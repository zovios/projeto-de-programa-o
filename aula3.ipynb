# %% [markdown]
# <a href="https://colab.research.google.com/github/zovios/projeto-de-programa-o/blob/main/aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# tipos numéricos
idade = 15 # int
altura = 1.65 # float
numero_complexo = 2 + 3j # complex

# tipo texto
nome = "Zovãozinho"

# tipo booleano
esta_chovendo = False # bool

# tipo lista (mutável)
numeros = [1, 2, 3, 4, 5] # list

# tipo tupla (imutavel)
coordenadas = (10, 20) # tuple

# tipo conjunto (valores únicos)
vogais = {'a', 'e', 'i', 'o', 'u',} # set

# tipo dicionário (chave-valor)
pessoa = {"nome": " Zovãozinho", "idade": 15, "altura": "1.65"} # dict

# %%
print (f"pessoa: {pessoa}")
# Out:
# pessoa: {'nome': ' Zovãozinho', 'idade': 15, 'altura': '1.65'}
